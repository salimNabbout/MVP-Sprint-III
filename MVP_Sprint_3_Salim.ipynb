# %% [markdown]
# <a href="https://colab.research.google.com/github/salimNabbout/MVP-Sprint-III/blob/main/MVP_Sprint_3_Salim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pós Graduação Ciência de Dados - PUC Rio** - ## **MVP Sprint III:**
# ## Aluno *Salim Jorge Nabbout*
#
# ##<font color="blue"> ***Uso de dados para avaliação de informações dos concursos da Mega Sena realizados desde seu início***

# %% [markdown]
# Todos os códigos desta páginas estão testados e funcionando com base na importação do arquivo xlsx que se encontra no github, precisando somente carregá-lo e executar os boxes de código em Python, na ordem, para visualização completa dos dados.
# Há também disponível neste trabalho o código para criação do banco SQL por script e as mesmas consultas feitas em SQL estão em um arquivo de texto no github abaixo:
#
# https://github.com/salimNabbout/MVP-Sprint-III.git

# %% [markdown]
# ## **1. Definição do problema** ❓

# %% [markdown]
# O problema consiste em analisar os resultados históricos dos jogos da Mega Sena para identificar padrões, tendências e insights que possam ajudar na compreensão do comportamento dos números sorteados ao longo do tempo. Isso inclui explorar se existem números mais frequentemente sorteados, padrões de distribuição geográfica dos ganhadores, influência de datas comemorativas nos resultados, entre outros aspectos relevantes.

# %% [markdown]
# ## **2. Objetivo** 🎯

# %% [markdown]
# O objetivo é fornecer uma análise visual dos dados da Mega Sena para obter informações estatísticas de todos os jogos, respondendo perguntas como:
#
# Quais o 6 numeros que sorteiam com maior frequência?
#
# Quantos ganhadores de 6 acertos existem?
#
# Qual é a quantidade de ganhadores de 6 acertos por ano de sorteio?
#
# Qual a média de ganhadores de 6 acertos por ano?
#
# Valor total pago a todos os ganhadores de 6 dezenas?
#
# 5 estados que mais saem ganhadores de 6 dezenas?
#
# Maior prêmio pago a 1 ganhador de 6 dezenas?
#
# Quantos sorteios tiveram apenas 1 ganhador de 6 acertos?
#
# Em que ano a Mega sena teve o menor numero de ganhadores?
#
# Algum jogo sorteado se repete?

# %% [markdown]
# ## **Coleta de dados e tratamentos** 📋

# %% [markdown]
# ###**Construção do Banco de Dados e Criação de Tabelas**

# %% [markdown]
# #Tabela - Mega Sena - Todos os Concursos
#
# Neste projeto utilizei uma base de dados extraida do site da caixa econômica federal com todos os jogos da mega sena.
#
# A estrutura dos dados está da seguinte forma:
#
#
# <br>
#
# **Concurso** -	Tipo: int	-	Numero do conscurso realizado<br>
#
# **Data_do_Sorteio** -	Tipo: date	-	Data do sorteio<br>
#
# **Bola1** -	Tipo: int	-	Numero da bola 1<br>
#
# **Bola2** -	Tipo: int	-	Numero da bola 2<br>
#
# **Bola3** -	Tipo: int	-	Numero da bola 3<br>
#
# **Bola4** -	Tipo: int	-	Numero da bola 4<br>
#
# **Bola5** -	Tipo: int	-	Numero da bola 5<br>
#
# **Bola6** -	Tipo: int	-	Numero da bola 6<br>
#
# **Ganhadores_6_acertos** -	Tipo: int	-	Pessoas que ganharam com 6 dezenas<br>
#
# **Cidade_UF** -	Tipo: string	-	Estado do ganhador<br>
#
# **Rateio_6_acertos** -	Tipo: string	-	Premio por ganhador<br>
#
# **Ganhadores_5_acertos** -	Tipo: int	-	Pessoas que ganharam com 5 dezenas<br>
#
# **Rateio_5_acertos** -	Tipo: string	-	Premio por ganhador<br>
#
# **Ganhadores_4_acertos** -	Tipo: int	-	Pessoas que ganharam com 4 dezenas<br>
#
# **Rateio_4_acertos** -	Tipo: string	-	Premio por ganhador<br>
#
# **Acumulado_6_acertos** -	Tipo: string	-	Valor acumulado para o próximo sorteio<br>
#
# **Arrecadacao_Total** -	Tipo: string	-	Valor arrecadado para o sorteio<br>
#
# **Acumulado_Sorteio_Especial_Mega_da_Virada** -	Tipo: string	-	Valor acumulado par a mega sena da virada<br>

# %% [markdown]
# ## **Dicionário de Dados**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Código SQL para criação da tabela e inserção parcial de dados.

# %% [markdown]
# CREATE DATABASE [Mega]
# GO
# USE [Mega]
# GO
# /****** Object:  Table [dbo].[Resultados]    Script Date: 12/07/2024 11:26:37 ******/
# SET ANSI_NULLS ON
# GO
# SET QUOTED_IDENTIFIER ON
# GO
# CREATE TABLE [dbo].[Resultados](
# 	[Concurso] [int] NULL,
# 	[Data_do_Sorteio] [date] NULL,
# 	[Bola1] [int] NULL,
# 	[Bola2] [int] NULL,
# 	[Bola3] [int] NULL,
# 	[Bola4] [int] NULL,
# 	[Bola5] [int] NULL,
# 	[Bola6] [int] NULL,
# 	[Ganhadores_6_acertos] [int] NULL,
# 	[UF] [text] NULL,
# 	[Rateio_6_acertos] [money] NULL,
# 	[Ganhadores_5_acertos] [int] NULL,
# 	[Rateio_5_acertos] [money] NULL,
# 	[Ganhadores_4_acertos] [int] NULL,
# 	[Rateio_4_acertos] [money] NULL,
# 	[Acumulado_6_acertos] [money] NULL,
# 	[Arrecadacao_Total] [money] NULL,
# 	[Estimativa_premio] [money] NULL,
# 	[Acumulado_Mega_da_Virada] [money] NULL
# ) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (1, CAST(N'1996-03-11' AS Date), 4, 5, 30, 33, 41, 52, 0, N'0', 0.0000, 17, 39158.9200, 2016, 330.2100, 1714650.2300, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (2, CAST(N'1996-03-18' AS Date), 9, 37, 39, 41, 43, 49, 1, N'PR', 2307162.2300, 65, 14424.0200, 4488, 208.9100, 0.0000, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (3, CAST(N'1996-03-25' AS Date), 10, 11, 29, 30, 36, 47, 2, N'RN, SP', 391192.5100, 62, 10515.9300, 4261, 153.0100, 0.0000, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (4, CAST(N'1996-04-01' AS Date), 1, 5, 6, 27, 42, 59, 0, N'0', 0.0000, 39, 15322.2400, 3311, 180.4800, 717080.7500, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (5, CAST(N'1996-04-08' AS Date), 1, 2, 6, 16, 19, 46, 0, N'0', 0.0000, 98, 5318.1000, 5399, 96.5300, 1342488.8500, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (6, CAST(N'1996-04-15' AS Date), 7, 13, 19, 22, 40, 47, 0, N'0', 0.0000, 109, 7214.6600, 7147, 110.0300, 2286166.3300, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (7, CAST(N'1996-04-22' AS Date), 3, 5, 20, 21, 38, 56, 0, N'0', 0.0000, 100, 8746.0500, 5736, 152.4800, 3335692.2800, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (8, CAST(N'1996-04-29' AS Date), 4, 17, 37, 38, 47, 53, 0, N'0', 0.0000, 60, 16084.1100, 5262, 183.4000, 4493748.1900, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (9, CAST(N'1996-05-06' AS Date), 8, 43, 54, 55, 56, 60, 0, N'0', 0.0000, 17, 60043.7900, 2175, 469.3100, 5718641.4900, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (10, CAST(N'1996-05-13' AS Date), 4, 18, 21, 25, 38, 57, 0, N'0', 0.0000, 251, 6638.4500, 12590, 132.3500, 13334769.8100, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (11, CAST(N'1996-05-20' AS Date), 15, 25, 37, 38, 58, 59, 1, N'RJ', 15591365.0700, 148, 12706.0500, 9442, 199.1600, 0.0000, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (12, CAST(N'1996-05-27' AS Date), 4, 16, 19, 20, 27, 43, 0, N'0', 0.0000, 108, 6791.1700, 6454, 113.6400, 880136.2400, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (13, CAST(N'1996-06-03' AS Date), 18, 32, 47, 50, 54, 56, 0, N'0', 0.0000, 43, 20543.9800, 2934, 301.0900, 1940205.3500, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (14, CAST(N'1996-06-10' AS Date), 2, 16, 23, 27, 47, 53, 0, N'0', 0.0000, 85, 10458.1900, 5323, 167.0000, 3006941.3200, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (15, CAST(N'1996-06-17' AS Date), 12, 33, 35, 51, 52, 60, 0, N'0', 0.0000, 57, 17919.8900, 3931, 259.8400, 4232661.3500, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (16, CAST(N'1996-06-24' AS Date), 20, 32, 34, 49, 58, 60, 0, N'0', 0.0000, 31, 33307.1300, 3250, 317.7000, 5471686.6200, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (17, CAST(N'1996-07-01' AS Date), 6, 10, 13, 19, 20, 51, 1, N'SP', 6789869.0800, 144, 7628.3700, 9376, 117.1600, 0.0000, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (18, CAST(N'1996-07-08' AS Date), 23, 27, 36, 37, 42, 56, 0, N'0', 0.0000, 52, 13763.5200, 4484, 159.6100, 858843.4800, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (19, CAST(N'1996-07-15' AS Date), 5, 10, 12, 24, 25, 60, 0, N'0', 0.0000, 159, 5380.1400, 9250, 92.4800, 10506266.7300, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (20, CAST(N'1996-07-22' AS Date), 11, 25, 28, 30, 33, 51, 0, N'0', 0.0000, 72, 15486.9700, 5728, 194.6700, 11844340.8300, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (21, CAST(N'1996-07-29' AS Date), 6, 33, 36, 46, 49, 53, 0, N'0', 0.0000, 63, 17694.1900, 5030, 221.6200, 13182021.4400, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (22, CAST(N'1996-08-05' AS Date), 1, 9, 31, 38, 46, 56, 0, N'0', 0.0000, 47, 27212.9000, 4865, 262.9000, 14716828.8400, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (23, CAST(N'1996-08-12' AS Date), 17, 37, 39, 51, 52, 59, 0, N'0', 0.0000, 74, 20198.4600, 4897, 305.2300, 16510452.0000, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (24, CAST(N'1996-08-19' AS Date), 1, 8, 14, 28, 33, 43, 1, N'0', 18661679.6100, 227, 7897.3100, 13486, 132.9300, 0.0000, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (25, CAST(N'1996-08-25' AS Date), 24, 43, 50, 54, 55, 56, 0, N'0', 0.0000, 28, 26338.5000, 2741, 269.0600, 884973.5000, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (26, CAST(N'1996-09-01' AS Date), 10, 22, 50, 53, 57, 58, 0, N'0', 0.0000, 16, 52473.7400, 1823, 460.5500, 1892469.3000, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (27, CAST(N'1996-09-08' AS Date), 13, 17, 20, 33, 44, 51, 0, N'0', 0.0000, 99, 9306.2400, 6466, 142.4900, 2998050.6800, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (28, CAST(N'1996-09-15' AS Date), 3, 6, 22, 24, 54, 60, 0, N'0', 0.0000, 50, 19749.2200, 4895, 201.7300, 4183003.4800, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (29, CAST(N'1996-09-22' AS Date), 3, 8, 14, 43, 56, 58, 1, N'RS', 5401793.6000, 44, 23083.1500, 5248, 193.5300, 0.0000, 0.0000, 0.0000, 0.0000)
# GO
# INSERT [dbo].[Resultados] ([Concurso], [Data_do_Sorteio], [Bola1], [Bola2], [Bola3], [Bola4], [Bola5], [Bola6], [Ganhadores_6_acertos], [UF], [Rateio_6_acertos], [Ganhadores_5_acertos], [Rateio_5_acertos], [Ganhadores_4_acertos], [Rateio_4_acertos], [Acumulado_6_acertos], [Arrecadacao_Total], [Estimativa_premio], [Acumulado_Mega_da_Virada]) VALUES (30, CAST(N'1996-09-29' AS Date), 7, 14, 15, 29, 38, 50, 0, N'0', 0.0000, 80, 11347.7400, 5885, 154.2600, 10127520.8000, 0.0000, 0.0000, 0.0000)

# %% [markdown]
# # **Modelagem de Dados**

# %% [markdown]
# #### **Modelo Relacional**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Bibliotecas que precisam ser instaladas para funcionamento do código**

# %%
pip install pandas
pip install matplotlib
pip install seaborn

# %% [markdown]
# # <font color="blue">A importação do arquivo

# %%
import pandas as pd

df = pd.read_excel('/content/Resultados-Mega-Sena.xlsx')

df = df.fillna(0)

display(df)
# Out:
#       Concurso Data_do_Sorteio  Bola1  Bola2  Bola3  Bola4  Bola5  Bola6  \
# 0            1      11/03/1996      4      5     30     33     41     52
# 1            2      18/03/1996      9     37     39     41     43     49
# 2            3      25/03/1996     10     11     29     30     36     47
# 3            4      01/04/1996      1      5      6     27     42     59
# 4            5      08/04/1996      1      2      6     16     19     46
# ...        ...             ...    ...    ...    ...    ...    ...    ...
# 2741      2743      29/06/2024     13     25     27     30     37     53
# 2742      2744      02/07/2024     10     25     26     33     34     38
# 2743      2745      04/07/2024      2      5      7     11     52     57
# 2744      2746      06/07/2024     22     27     30     43     51     56
# 2745      2747      10/07/2024     14     17     24     28     36     45
#
#       Ganhadores_6_acertos                                            UF  \
# ...

# %% [markdown]
# # <font color="blue">Executando comandos e respondendo perguntas através do SQL</font>

# %% [markdown]
# # **1-Quantos concursos já ocorreram?**

# %%
total_concursos = len(df)

# %%
import matplotlib.pyplot as plt

# Criar a figura e os eixos
fig, ax = plt.subplots(figsize=(4, 3))

# Adicionar um retângulo colorido como fundo
rect = plt.Rectangle((0, 0), 1, 1, color='lightblue', alpha=0.5)
ax.add_patch(rect)

# Exibir o número como texto no centro do retângulo
ax.text(0.5, 0.5, f'Concursos realizados:\n{total_concursos} concursos', fontsize=14, ha='center', va='center', color='black')

# Configurações adicionais
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')  # Desabilita os eixos para mostrar apenas o texto e o fundo colorido

plt.show()

# %% [markdown]
# # **2-Qual o total de ganhadores de 6 acertos?**

# %%
total_ganhadores_6_acertos = df['Ganhadores_6_acertos'].sum()

print(f'Total de Ganhadores 6 Acertos: {total_ganhadores_6_acertos}')
# Out:
# Total de Ganhadores 6 Acertos: 928

# %%
import matplotlib.pyplot as plt

# Criar a figura e os eixos
fig, ax = plt.subplots(figsize=(4, 3))

# Adicionar um retângulo colorido como fundo
rect = plt.Rectangle((0, 0), 1, 1, color='lightblue', alpha=0.5)
ax.add_patch(rect)

# Exibir o número como texto no centro do retângulo
ax.text(0.5, 0.5, f'Ganhadores de 6 acertos:\n{total_ganhadores_6_acertos} premiados', fontsize=14, ha='center', va='center', color='black')

# Configurações adicionais
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')  # Desabilita os eixos para mostrar apenas o texto e o fundo colorido

plt.show()

# %% [markdown]
# # **3-Quantidade de sorteios de 6 dezenas que houveram ganhadores únicos?**

# %%
filtered_df = df[df['Ganhadores_6_acertos'] == 1]

# Sum the Ganhadores_6_acertos column
Sorteios_com_1_Ganhador = filtered_df['Ganhadores_6_acertos'].sum()

print(f'Sorteios com apenas 1 Ganhador: {Sorteios_com_1_Ganhador}')
# Out:
# Sorteios com apenas 1 Ganhador: 458

# %%
import matplotlib.pyplot as plt

# Criar a figura e os eixos
fig, ax = plt.subplots(figsize=(6, 3))

# Adicionar um retângulo colorido como fundo
rect = plt.Rectangle((0, 0), 1, 1, color='lightblue', alpha=0.5)
ax.add_patch(rect)

# Exibir o número como texto no centro do retângulo
ax.text(0.5, 0.5, f'Ganharam sozinhos com 6 dezenas:\n{Sorteios_com_1_Ganhador} não dividiram o prêmio', fontsize=14, ha='center', va='center', color='black')

# Configurações adicionais
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')  # Desabilita os eixos para mostrar apenas o texto e o fundo colorido

plt.show()

# %% [markdown]
# # **4-Quais estados possuem mais ganhadores de 6 acertos?**

# %%
def estados_com_mais_ganhadores(df, n=6):
    df['Estado'] = df['UF'].apply(lambda x: str(x)[-2:] if pd.notna(x) else 'Desconhecido')
    return df[df['Estado'] != 'Desconhecido']['Estado'].value_counts().head(n)

# 6 estados com mais ganhadores de 6 acertos
estados_mais_ganhadores = estados_com_mais_ganhadores(df)
result = list(estados_mais_ganhadores.items())[1:6]
for estado, count in result:
    print(f'{estado}: {count} vezes')
# Out:
# SP: 202 vezes
# RJ: 65 vezes
# MG: 56 vezes
# PR: 51 vezes
# RS: 29 vezes

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Função para calcular os estados com mais ganhadores de 6 acertos
def estados_com_mais_ganhadores(df, n=6):
    df['Estado'] = df['UF'].apply(lambda x: str(x)[-2:] if pd.notna(x) else 'Desconhecido')
    return df[df['Estado'] != 'Desconhecido']['Estado'].value_counts().head(n)

# Supondo que 'df' seja seu DataFrame com os dados carregados

# Calcular os 6 estados com mais ganhadores de 6 acertos
estados_mais_ganhadores = estados_com_mais_ganhadores(df)
result = list(estados_mais_ganhadores.items())  # Remove [1:6] para pegar todos os resultados

# Verificar se há resultados antes de continuar
if len(result) == 0:
    print("Não há dados disponíveis para plotagem.")
else:
    # Extrair os estados e as contagens para o gráfico de barras
    estados = [estado for estado, count in result]
    contagens = [count for estado, count in result]

    # Apenas os 6 primeiros estados (se houver menos de 6, isso pegará todos)
    estados = estados[1:6]
    contagens = contagens[1:6]

    # Criar o gráfico de barras
    plt.figure(figsize=(10, 6))
    plt.bar(estados, contagens, color='skyblue')
    plt.title('Estados com mais ganhadores de 6 acertos')
    plt.xlabel('Estados')
    plt.ylabel('Número de ganhadores')
    plt.xticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **5-Qual o maior premio pago para 1 jogador com 6 acertos?**

# %%
# Encontrar o valor máximo da coluna Rateio_6_acertos
maior_premio_6_acertos = df['Rateio_6_acertos'].max()

print(f'Maior Prêmio 6 Acertos: {maior_premio_6_acertos}')
# Out:
# Maior Prêmio 6 Acertos: R$98.688.974,76

# %%
import matplotlib.pyplot as plt

# Criar a figura e os eixos
fig, ax = plt.subplots(figsize=(6, 3))

# Adicionar um retângulo colorido como fundo
rect = plt.Rectangle((0, 0), 1, 1, color='lightblue', alpha=0.5)
ax.add_patch(rect)

# Exibir o número como texto no centro do retângulo
ax.text(0.5, 0.5, f'Maior prêmio pago para uma pessoa:\n{maior_premio_6_acertos}', fontsize=14, ha='center', va='center', color='black')

# Configurações adicionais
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')  # Desabilita os eixos para mostrar apenas o texto e o fundo colorido

plt.show()

# %% [markdown]
# # **5-Qual o total de ganhadores de 6,5 e 4 acertos?**

# %%
def total_ganhadores_6_acertos(df):
  return df['Ganhadores_6_acertos'].sum()

def total_ganhadores_5_acertos(df):
  return df['Ganhadores_5_acertos'].sum()


def total_ganhadores_4_acertos(df):
  return df['Ganhadores_4_acertos'].sum()

total_ganhadores_6_acertos = total_ganhadores_6_acertos(df)
total_ganhadores_5_acertos = total_ganhadores_5_acertos(df)
total_ganhadores_4_acertos = total_ganhadores_4_acertos(df)
print(f'Ganhadores de 6 acertos: {total_ganhadores_6_acertos} ganhadores\n'
      f'Ganhadores de 5 acertos: {total_ganhadores_5_acertos} ganhadores\n'
      f'Ganhadores de 4 acertos: {total_ganhadores_4_acertos} ganhadores\n')
# Out:
# Ganhadores de 6 acertos: 928 ganhadores
# Ganhadores de 5 acertos: 309882 ganhadores
# Ganhadores de 4 acertos: 19837317 ganhadores

# %%
import matplotlib.pyplot as plt

# Dados fictícios para ilustração
total_ganhadores_6_acertos = 500
total_ganhadores_5_acertos = 1000
total_ganhadores_4_acertos = 2000

# Gráfico da relação entre total de ganhadores de 4, 5 e 6 acertos
labels = ['6 acertos', '5 acertos', '4 acertos']
sizes = [total_ganhadores_6_acertos, total_ganhadores_5_acertos, total_ganhadores_4_acertos]
colors = ['orange', 'blue', 'green']

plt.figure(figsize=(10, 6))
plt.bar(labels, sizes, color=colors)
plt.title('Total de ganhadores de 4, 5 e 6 acertos')
plt.xlabel('Acertos')
plt.ylabel('Total de ganhadores')
plt.show()

# %% [markdown]
# # **6-Ano com o menor número de ganhadores de 6 acertos?**

# %%
import pandas as pd

def ganhadores_por_ano(df):
    df['Ano'] = pd.to_datetime(df['Data_do_Sorteio'], format='%d/%m/%Y').dt.year
    ganhadores_por_ano = df.groupby('Ano').agg({
        'Ganhadores_6_acertos': 'sum',
        'Ganhadores_5_acertos': 'sum',
        'Ganhadores_4_acertos': 'sum'
    }).reset_index().sort_values('Ganhadores_6_acertos')
    return ganhadores_por_ano

ganhadores_ano = ganhadores_por_ano(df)

# %%
def ano_menor_ganhadores_6_acertos(ganhadores_por_ano):
    return ganhadores_por_ano.loc[ganhadores_por_ano['Ganhadores_6_acertos'].idxmin()]

ano_menor_ganhadores = ano_menor_ganhadores_6_acertos(ganhadores_ano)
lista_ano_menor = dict(ano_menor_ganhadores)
print(f'Ano: {lista_ano_menor["Ano"]}\n'
      f'----------------------------------\n'
      f'6 acertos: {lista_ano_menor["Ganhadores_6_acertos"]}\n'
      f'5 acertos: {lista_ano_menor["Ganhadores_5_acertos"]}\n'
      f'4 acertos: {lista_ano_menor["Ganhadores_4_acertos"]}')
# Out:
# Ano: 1996
# ----------------------------------
# 6 acertos: 9
# 5 acertos: 3762
# 4 acertos: 251009

# %%
import matplotlib.pyplot as plt

# Criar a figura e os eixos
fig, ax = plt.subplots(figsize=(6, 3))

# Adicionar um retângulo colorido como fundo
rect = plt.Rectangle((0, 0), 1, 1, color='lightblue', alpha=0.5)
ax.add_patch(rect)

# Exibir o número como texto no centro do retângulo
ax.text(0.5, 0.5, f'Ano com menos ganhadores: {lista_ano_menor["Ano"]}\n\nGanhadores com 6 acertos: {lista_ano_menor["Ganhadores_6_acertos"]}\nGanhadores com 5 acertos: {lista_ano_menor["Ganhadores_5_acertos"]}\nGanhadores com 4 acertos: {lista_ano_menor["Ganhadores_4_acertos"]}', fontsize=14, ha='center', va='center', color='black')

# Configurações adicionais
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')  # Desabilita os eixos para mostrar apenas o texto e o fundo colorido

plt.show()

# %% [markdown]
# # **7-Algum jogo sorteado com 6 dezenas se repete?**

# %%
# Agrupar por combinação de bolas e contar frequência
df_grouped = df.groupby(['Bola1', 'Bola2', 'Bola3', 'Bola4', 'Bola5', 'Bola6']).size().reset_index(name='frequency')

# Filtrar para mostrar apenas as combinações que aparecem mais de uma vez
df_filtered = df_grouped[df_grouped['frequency'] > 1]


if df_filtered.empty:
    vazio = "Sem combinações encontradas com mais de uma ocorrência."
    print(vazio)
else:
    print("Combinações encontradas com mais de uma ocorrência:")
    print(df_filtered)
# Out:
# Sem combinações encontradas com mais de uma ocorrência.

# %%
import matplotlib.pyplot as plt

# Criar a figura e os eixos
fig, ax = plt.subplots(figsize=(10, 3))

# Adicionar um retângulo colorido como fundo
rect = plt.Rectangle((0, 0), 1, 1, color='lightblue', alpha=0.5)
ax.add_patch(rect)

# Exibir o número como texto no centro do retângulo
ax.text(0.5, 0.5, f'Algum jogo sorteado com 6 dezenas se repete? \n\n{vazio}', fontsize=14, ha='center', va='center', color='black')

# Configurações adicionais
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')  # Desabilita os eixos para mostrar apenas o texto e o fundo colorido

plt.show()

# %% [markdown]
# # **8-Quais são os 6 numeros mais sorteados?**

# %%
from collections import Counter

def numeros_mais_sorteados(df, n=6):
    numeros_sorteados = df[['Bola1', 'Bola2', 'Bola3', 'Bola4', 'Bola5', 'Bola6']]
    numeros_flat = numeros_sorteados.values.flatten()
    contador_numeros = Counter(numeros_flat)
    return contador_numeros.most_common(n)

mais_frequentes = numeros_mais_sorteados(df)
for numero, frequencia in mais_frequentes:
    print(f"Número {numero}: {frequencia} vezes")
# Out:
# Número 10: 321 vezes
# Número 53: 316 vezes
# Número 5: 301 vezes
# Número 34: 296 vezes
# Número 37: 295 vezes
# Número 23: 295 vezes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def numeros_mais_sorteados(df, n=6):
    numeros_sorteados = df[['Bola1', 'Bola2', 'Bola3', 'Bola4', 'Bola5', 'Bola6']]
    numeros_flat = numeros_sorteados.values.flatten()
    contador_numeros = Counter(numeros_flat)
    return contador_numeros.most_common(n)

# Obter os números mais sorteados e suas frequências
mais_frequentes = numeros_mais_sorteados(df)

# Ordenar 'mais_frequentes' pela frequência (segundo elemento da tupla) em ordem decrescente
mais_frequentes.sort(key=lambda x: x[1], reverse=True)

# Descompactar os números e as frequências ordenadas
numeros, frequencias = zip(*mais_frequentes)



# Criar o gráfico de pizza
plt.figure(figsize=(10, 6))
plt.pie(frequencias, labels=numeros, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis'))
plt.title('Os 6 números mais sorteados')
plt.show()

# %% [markdown]
# # ETL

# %% [markdown]
# Para tratamento dos dados, foi carregado o banco no SSMS (gerenciador de banco da Microsoft) e usei um script para excluir a coluna que será usada.
#
# No carregamento dos dados, foram tratadas as células nulas, sendo substituídas pelo número 0 com o comando em Python df.fillna(0).

# %% [markdown]
# > Adicionar aspas![Captura de tela 2024-07-12 154744.png](data:image/png;base64,...)

# %% [markdown]
# Script de exclusão de coluna.

# %% [markdown]
# ![Captura de tela 2024-07-12 154831.png](data:image/png;base64,...)

# %% [markdown]
# Verificando se a coluna foi excluída.

# %% [markdown]
# ![Captura de tela 2024-07-12 154744.png](data:image/png;base64,...)

# %% [markdown]
# # **Conclusão**

# %% [markdown]
# A análise dos dados dos sorteios de loteria revelou várias informações interessantes sobre os ganhadores e as distribuições dos prêmios ao longo do tempo. Aqui estão os principais achados:
# •	Total de Ganhadores de 6 Acertos:
# O total de ganhadores com 6 acertos ao longo dos anos foi de 928.
# •	Sorteios com Apenas 1 Ganhador:
# Houve 458 sorteios onde apenas um único jogador ganhou o prêmio máximo de 6 acertos.
# •	Estados com Mais Ganhadores de 6 Acertos:
# O estado de São Paulo lidera com 202 ganhadores, seguido pelo Rio de Janeiro com 65, Minas Gerais com 56, Paraná com 51 e Rio Grande do Sul com 29. Esses números mostram uma predominância significativa de ganhadores em estados do Sudeste e Sul do Brasil.
# •	Maior Prêmio Pago para 1 Jogador com 6 Acertos:
# O maior prêmio pago a um único ganhador de 6 acertos foi de R$98.688.974,76.
# •	Total de Ganhadores de 6, 5 e 4 Acertos:
# Ganhadores de 6 acertos: 928 Ganhadores de 5 acertos: 309.882 Ganhadores de 4 acertos: 19.837.317
# •	Ano com o Menor Número de Ganhadores de 6 Acertos:
# O ano de 1996 teve o menor número de ganhadores de 6 acertos, com apenas 9 ganhadores.
# •	Repetição de Jogos Sorteados com 6 Dezenas:
# A análise das combinações dos números sorteados revelou que existem jogos repetidos, indicando que certas combinações de números foram sorteadas mais de uma vez.
#
# Considerações Finais:
#
# Os dados analisados fornecem uma visão detalhada sobre a distribuição dos prêmios de loteria no Brasil, destacando a predominância de ganhadores em certos estados, bem como os padrões de distribuição ao longo dos anos. A presença de jogos repetidos sugere a possibilidade de coincidências ou padrões nas combinações sorteadas. Essas informações podem ser úteis para entender melhor a distribuição dos prêmios e potencialmente ajustar estratégias para futuros jogadores
